# %% [markdown]
# # Exploration
#
# Scratch notebook for poking at the data. Anything reusable should move to `dashboard.py` or `dusko_utils`.

# %%
from pathlib import Path
import pandas as pd
import plotly.express as px

DATA_DIR = Path.cwd() / "data"

# df = pd.read_csv(DATA_DIR / "your_file.csv")
# df.head()

# %%
# Quick profile
# df.info()
# df.describe(include="all")

# %%
# Example chart
# px.histogram(df, x="some_column")
